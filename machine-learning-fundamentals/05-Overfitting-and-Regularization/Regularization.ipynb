# %% [markdown]
# # Regularization
# Here we will practice to extend the previous concepts of machine learning by adding a regularization element to prevent overfitting.
#
# The description for the **regularized logistic regression** concepts are explained in the [README](https://github.com/mohammadkhoubrou/machine-learning-deep-learning-foundations-from-scratch/tree/main/machine-learning-fundamentals/05-Overfitting-and-Regularization) file.

# %% [markdown]
# ## how to compute the cost function
# The regularization factor controls how large the weights should be. In other words, using this factor, gradient descent minimizes the saze of the weights.
# ### L2 regularization
# Simply by adding the square of weights and multiplying it to the $\frac{λ}{2m}$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(z):
    g = 1/(1+np.exp(-z))
    return g

# %%
def reg_cost(x, y, w, b, lam = 1):
    m,n  = x.shape
    cost = 0.
    for i in range(m):
        z_i = np.dot(x[i], w) + b                                    
        f_i = sigmoid(z_i)                                        
        cost +=  -y[i]*np.log(f_i) - (1-y[i])*np.log(1-f_i)    
             
    cost = cost/m                                                 

    reg_cost = 0
    for j in range(n):
        reg_cost += (w[j]**2)                                     
    reg_cost = (lam/(2*m)) * reg_cost                              
    
    total_cost = cost + reg_cost                      
    return total_cost

# %%
def compute_gradient_linear_reg(X, y, w, b, lambda_): 

    m,n = X.shape          
    dj_dw = np.zeros((n,))
    dj_db = 0.

    for i in range(m):                             
        err = (np.dot(X[i], w) + b) - y[i]                 
        for j in range(n):                         
            dj_dw[j] = dj_dw[j] + err * X[i, j]               
        dj_db = dj_db + err                        
    dj_dw = dj_dw / m                                
    dj_db = dj_db / m   
    
    for j in range(n):
        dj_dw[j] = dj_dw[j] + (lambda_/m) * w[j]

    return dj_db, dj_dw

# %%
def compute_gradient_logistic_reg(X, y, w, b, lambda_): 
    m,n = X.shape
    dj_dw = np.zeros((n,))                      
    dj_db = 0.0                                     

    for i in range(m):
        f_wb_i = sigmoid(np.dot(X[i],w) + b)         
        err_i  = f_wb_i  - y[i]                       
        for j in range(n):
            dj_dw[j] = dj_dw[j] + err_i * X[i,j]     
        dj_db = dj_db + err_i
    dj_dw = dj_dw/m                                   
    dj_db = dj_db/m                                   

    for j in range(n):
        dj_dw[j] = dj_dw[j] + (lambda_/m) * w[j]

    return dj_db, dj_dw
